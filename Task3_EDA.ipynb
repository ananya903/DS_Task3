# %% [markdown]
# ## Grip @The Sparks Foundation
#
# ## Name : Ananya
#
# ## Data Science and Business Analytics Intern

# %% [markdown]
# ## TASK 3 - Exploratory Data Analysis - Retail
#
# ● Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#
# ● As a business manager, try to find out the weak areas where you can
#   work to make more profit.
#
# ● What all business problems you can derive by exploring the data?

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("SampleSuperstore.csv")
df.head(15)
# Out:
#          Ship Mode      Segment        Country             City  \
# 0     Second Class     Consumer  United States        Henderson
# 1     Second Class     Consumer  United States        Henderson
# 2     Second Class    Corporate  United States      Los Angeles
# 3   Standard Class     Consumer  United States  Fort Lauderdale
# 4   Standard Class     Consumer  United States  Fort Lauderdale
# 5   Standard Class     Consumer  United States      Los Angeles
# 6   Standard Class     Consumer  United States      Los Angeles
# 7   Standard Class     Consumer  United States      Los Angeles
# 8   Standard Class     Consumer  United States      Los Angeles
# 9   Standard Class     Consumer  United States      Los Angeles
# 10  Standard Class     Consumer  United States      Los Angeles
# 11  Standard Class     Consumer  United States      Los Angeles
# 12  Standard Class     Consumer  United States          Concord
# 13  Standard Class     Consumer  United States          Seattle
# 14  Standard Class  Home Office  United States       Fort Worth
#
#              State  Postal Code   Region         Category Sub-Category  \
# 0         Kentucky        42420    South        Furniture    Bookcases
# 1         Kentucky        42420    South        Furniture       Chairs
# 2       California        90036     West  Office Supplies       Labels
# 3          Florida        33311    South        Furniture       Tables
# 4          Florida        33311    South  Office Supplies      Storage
# 5       California        90032     West        Furniture  Furnishings
# 6       California        90032     West  Office Supplies          Art
# 7       California        90032     West       Technology       Phones
# 8       California        90032     West  Office Supplies      Binders
# 9       California        90032     West  Office Supplies   Appliances
# 10      California        90032     West        Furniture       Tables
# 11      California        90032     West       Technology       Phones
# 12  North Carolina        28027    South  Office Supplies        Paper
# 13      Washington        98103     West  Office Supplies      Binders
# 14           Texas        76106  Central  Office Supplies   Appliances
#
#         Sales  Quantity  Discount    Profit
# 0    261.9600         2      0.00   41.9136
# 1    731.9400         3      0.00  219.5820
# 2     14.6200         2      0.00    6.8714
# 3    957.5775         5      0.45 -383.0310
# 4     22.3680         2      0.20    2.5164
# 5     48.8600         7      0.00   14.1694
# 6      7.2800         4      0.00    1.9656
# 7    907.1520         6      0.20   90.7152
# 8     18.5040         3      0.20    5.7825
# 9    114.9000         5      0.00   34.4700
# 10  1706.1840         9      0.20   85.3092
# 11   911.4240         4      0.20   68.3568
# 12    15.5520         3      0.20    5.4432
# 13   407.9760         3      0.20  132.5922
# 14    68.8100         5      0.80 -123.8580

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (9977, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ###  *Exploratory Data Analysis

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Sales'],color='black',label='Sales',shade=True)
sns.kdeplot(df['Profit'],color='red',label='Profit',shade=True)
plt.xlim([-100,1000])
plt.legend()

# %% [markdown]
# Profit is more than sales but in some cases its vice-versa.

# %%
sns.lineplot(x='Discount',y='Profit',data = df)
plt.show()

# %% [markdown]
# Profit decreases with increase in discount

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %%
sns.heatmap(df.corr(),cmap='rocket_r',annot=True,linecolor='white',linewidth=2,cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Sales and Profit are Moderately Correlated.
#
# Discount and Profit are Negatively Correlated.
#
# Quantity and sales are also correlated but less than moderate.

# %%
sns.pairplot(df,hue='Category',palette='husl')

# %%
sns.pairplot(df,hue='Region')

# %%
#Count  plot of each column 
import warnings
warnings.filterwarnings("ignore")

fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(df['Category'],ax=axs[0][0])
sns.countplot(df['Segment'],ax=axs[0][1])
sns.countplot(df['Ship Mode'],ax=axs[1][0])
sns.countplot(df['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)
plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['Sub-Category'])
plt.title('Sub-Category',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %%
plt.figure(figsize=(18,10))
sns.countplot(df['State'])
plt.xticks(rotation=90)
plt.title('State',fontsize=20)
# Out:
# Text(0.5, 1.0, 'State')

# %%
plt.figure(figsize=(18,10))
sns.countplot(df['Discount'])
plt.xticks(rotation=90)
plt.title('Discount',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Discount')

# %%
#Distribution of the data using the plot

# %%
fig, axs = plt.subplots(ncols=2, nrows = 2, figsize = (20,10))
sns.distplot(df['Sales'], color = 'red',  ax = axs[0][0])
sns.distplot(df['Profit'], color = 'cyan',  ax = axs[0][1])
sns.distplot(df['Quantity'], color = 'magenta',  ax = axs[1][0])
sns.distplot(df['Discount'], color = 'blue',  ax = axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize = 20)
axs[0][1].set_title('Profit Distribution', fontsize = 20)
axs[1][0].set_title('Quantity distribution', fontsize = 20)
axs[1][1].set_title('Discount Distribution', fontsize = 20)
plt.show()

# %%
df1 = df['State'].value_counts()
df1.head(20)
# Out:
# California        1996
# New York          1127
# Texas              983
# Pennsylvania       586
# Washington         502
# Illinois           491
# Ohio               468
# Florida            383
# Michigan           254
# North Carolina     249
# Arizona            224
# Virginia           224
# Georgia            184
# Tennessee          183
# Colorado           182
# Indiana            149
# Kentucky           139
# Massachusetts      135
# New Jersey         130
# Oregon             123
# Name: State, dtype: int64

# %%
df1.plot(kind='pie',figsize=(35,25),autopct = '%1.1f%%')
plt.ylabel('Frequency / Number of deals',fontsize=20)
plt.xlabel('States',fontsize=20)

plt.title('State Wise Dealings', fontsize = 20)
plt.show()

# %%
df['State'].value_counts().mean()
# Out:
# 203.6122448979592

# %%
df2 = df['City'].value_counts()
df2=df2.head(50)
df2.plot(kind='pie',figsize=(25,25),autopct = '%1.1f%%')
plt.ylabel('Frequency / Number of deals',fontsize=20)
plt.xlabel('City',fontsize=20)

plt.title('City Wise Dealings', fontsize = 20)
plt.show()

# %%
Sales = df.groupby('Region').sum()['Sales'].sort_values(ascending = False)
Profits = df.groupby('Region').sum()['Profit'].sort_values(ascending = False)
plt.style.use('seaborn')
Sales.plot(kind='bar', figsize=(10,5),fontsize = 15, color = 'Red')
Profits.plot(kind='bar', figsize=(10,5),fontsize = 15 , color='Black')
plt.xlabel('Regions',fontsize =  20)
plt.ylabel('Total sales & profit',fontsize = 20)
plt.title("Sales vs Profit",fontsize = 20)
plt.show()

# %%
df['City'].value_counts().mean()
# Out:
# 18.789077212806028

# %%
#Citywise Analysis of the Profit

df_city= df.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
df_city = df_city.sort_values('Profit')
df_city.head()
# Out:
#                  Sales  Discount      Profit
# City
# Bethlehem   337.926800  0.380000 -200.619160
# Champaign   151.960000  0.600000 -182.352000
# Oswego      107.326000  0.600000 -178.709200
# Round Rock  693.436114  0.274286 -169.061614
# Lancaster   215.031826  0.315217 -157.371052

# %%
#1.Low Profit
df_city['Profit'].head(30).plot(kind='bar',figsize=(15,5),color = 'cyan')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale, Discount, profit')

# %%
#2. High Profit
df_city['Profit'].tail(30).plot(kind='bar',figsize=(15,5),color = 'cyan')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale, Discount, profit')

# %%
df_state= df.groupby([ 'State' ])[['Sales', 'Discount', 'Profit']].mean()
df_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            229.246629  0.072946   38.241878
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %%
df_state1=df_state.sort_values('Profit')

df_state1[['Profit']].plot(kind = 'bar', figsize = (15,4))
plt.title('State wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per Sate')
plt.xlabel('States')
plt.show()

# %%
#CATAGORY WISE SALES DISCOUNT AND PROFIT

df_category = df.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        350.002981  0.174027   8.697740
# Office Supplies  119.550107  0.157385  20.353403
# Technology       452.709276  0.132323  78.752002

# %%
df_category.plot.pie(subplots=True, 
                     figsize=(18, 20), 
                     autopct='%1.1f%%', 
                     labels = df_category.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %%
min_p = df.groupby('Sub-Category').min()['Profit'].sort_values()

# %%
plt.figure(figsize=(8,6))
min_p.plot()
plt.title('Sub-Categories with highest loss')
plt.xticks(rotation = 60 , fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()

# %%
#Sub-Category wise Sales, Profit and Discount

df_sub_category = df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
df_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.096896  0.074969    8.207059
# Binders        133.645972  0.372011   19.860710
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.971969  0.170244   43.198582
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.902745  0.138494   13.653476

# %%
plt.figure(figsize = (10,10))
plt.pie(df_sub_category['Sales'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sales Analysis(Sub-Category Wise)', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.pie(df_sub_category['Discount'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Discount Analysis(Sub-Category Wise)', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Concluding the Analysis:-
#
# 1. profit Percentage is more than that of sales but in some cases its vice-versa.
# 2. Sales and Profit are Moderately Correlated.
# 3. Discount and Profit are Negatively Correlated.
# 4. Wyoming : Lowest Number of deal,Highest amount of sales= Wyoming(11.8%)
# 5. Lowest amount of sales= South Dakota(0.8%)
# 6. Califonia,New York,Texas are the three states with highest deals.
# 7. Ohi has the Lowest Profit and Vermont has the highest profit.
# 8. Sales is high for Same day ship.
# 9. New York city has the highest city wise dealings.

# %% [markdown]
# West region shows more sales and more profit whereas central region shows least sales and profits. So, one should try to increase sales and profits in central region. Profit percentage can be increased in some cases than sales. The loss in subcategories can be converted into profit percentage.

# %% [markdown]
# THANK YOU !!
